# %%
import pandas as pd
import numpy as np

# %%
file = 'Datasets/data.csv'
file_df = pd.read_csv(file)
File_df = pd.DataFrame(file_df)
File_df['Countries'].value_counts().head(25)
America = File_df.loc[(File_df['Countries'] == 'United States of America') |
                      (File_df['Countries'] == 'Mexico') |
                      (File_df['Countries'] == 'Canada') |
                      (File_df["Countries"] == 'Canada, United States of America'),:]
America
# Out:
#         ID                             Name in English  \
# 68    1506                            Huasteca Náhuatl
# 82    1503                             Central Náhuatl
# 156    784                                      Navajo
# 160    916                              Sierra Totonac
# 166    904                                 Phurhepecha
# ...    ...                                         ...
# 2703  2391                          Tuscarora (Canada)
# 2706   280                                       Unami
# 2707  2392                       Upper Tanana (Canada)
# 2711  2393                    Western Abenaki (Canada)
# 2712   283  Western Abenaki (United States of America)
#
#                                    Name in French  \
# 68                            náhuatl du Huasteca
# 82                                náhuatl central
# 156                                        navajo
# 160                        totonaque de la Sierra
# 166                                     purepecha
# ...                                           ...
# 2703                           tuscarora (Canada)
# 2706                                     delaware
# 2707                         haut-tanana (Canada)
# 2711                 abénaqui occidental (Canada)
# 2712  abénaqui occidental (États-Unis d'Amérique)
#
#                           Name in Spanish                 Countries  \
# 68                   nahua de la Huasteca                    Mexico
# 82                          nahua central                    Mexico
# 156                                navajo  United States of America
# 160                  totonacano de Sierra                    Mexico
# 166                             purépecha                    Mexico
# ...                                   ...                       ...
# 2703                   tuscarora (Canadá)                    Canada
# 2706                                unamí  United States of America
# 2707                tanana alto  (Canadá)                    Canada
# 2711          abenakí occidental (Canadá)                    Canada
# 2712  abenakí occidental (Estados Unidos)  United States of America
#
#      Country codes alpha 3 ISO639-3 codes Degree of endangerment  \
# 68                     MEX            nhe             Vulnerable
# 82                     MEX  nhn, nch, ncx             Vulnerable
# 156                    USA            nav             Vulnerable
# 160                    MEX            tos    Severely endangered
# 166                    MEX            tsz             Vulnerable
# ...                    ...            ...                    ...
# 2703                   CAN            tus  Critically endangered
# 2706                   USA            unm                Extinct
# 2707                   CAN            tau  Critically endangered
# 2711                   CAN            abe  Critically endangered
# 2712                   USA            abe                Extinct
#
#                                  Alternate names Name in the language  \
# 68                                      Mexicano                  NaN
# 82             Mexicano, Aztec (in English only)                  NaN
# 156                                 Navajo, Diné                  NaN
# 160   Highland Totonac, Totonaco central del sur                  NaN
# 166                    Purépecha, Tarasco, Porhé                  NaN
# ...                                          ...                  ...
# 2703                                         NaN                  NaN
# 2706         Delaware, Oklahoma Delaware, Lenape                  NaN
# 2707                                         NaN                  NaN
# 2711                                         NaN                  NaN
# 2712                                         NaN                  NaN
#
#       Number of speakers                                            Sources  \
# 68              463183.0  Census 2000, information provided by INALI for...
# 82              395581.0  Census 2000, information provided by INALI for...
# 156             120000.0  Platero, Paul. 2001. Navajo head start languag...
# 160             118367.0  Contributors: Carolyn MacKay and Frank Tresche...
# 166             102988.0  Census 2000\nContributor:  Claudine Chamoreau ...
# ...                  ...                                                ...
# 2703                 NaN  1996 and 2001 Censuses, Statistics Canada; bas...
# 2706                 NaN                                    Golla et al ms.
# 2707                 NaN  1996 and 2001 Censuses, Statistics Canada; bas...
# 2711                 NaN  1996 and 2001 Censuses, Statistics Canada; bas...
# 2712                 NaN  Victor Golla, Ives Goddard, Lyle Campbell, Mar...
#
#       Latitude  Longitude                        Description of the location
# 68     21.3835   -98.9902  Locality of Xilitla and others in the municipa...
# 82     19.1910   -99.0236  Locality of Milpa Alta and others with few rem...
# 156    35.8044  -108.4750  the Navajo Nation is located in the region of ...
# 160    20.2461   -97.6586  Ahuacatlán, Amixtlán, Atlequizayán, Camocuautl...
# 166    19.3111  -102.0410                                                NaN
# ...        ...        ...                                                ...
# 2703   43.0720   -80.0150                Spread over 2 communities in Canada
# 2706   39.1300   -76.0253                                                NaN
# 2707   62.3824  -140.8984                Spread over 1 communities in Canada
# 2711   46.0785   -72.8141                Spread over 2 communities in Canada
# 2712   43.0046   -72.2460                                                NaN
#
# [452 rows x 15 columns]

# %%
File_DF = America.iloc[:, [0, 1, 4, 7, 10, 12, 13, 14]]
Count = pd.DataFrame(File_DF.groupby(['Countries']).count()['Degree of endangerment'])
Count.plot(kind='barh')

# %%
Degree = pd.DataFrame(File_DF.groupby(['Countries', 'Degree of endangerment']).count()['ID'])
degree = Degree.iloc[8:12]
degree.plot(kind='pie', subplots='True')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001803DB02E08>],
#       dtype=object)

# %%
Degree
# Out:
#                                                          ID
# Countries                        Degree of endangerment
# Canada                           Critically endangered   28
#                                  Definitely endangered   16
#                                  Extinct                  2
#                                  Severely endangered     12
#                                  Vulnerable              24
# Canada, United States of America Critically endangered    4
#                                  Definitely endangered    2
#                                  Severely endangered      5
# Mexico                           Critically endangered   21
#                                  Definitely endangered   38
#                                  Severely endangered     32
#                                  Vulnerable              52
# United States of America         Critically endangered   80
#                                  Definitely endangered   28
#                                  Extinct                 54
#                                  Severely endangered     40
#                                  Vulnerable              14

# %%
df2 = pd.DataFrame({
    'Degree': ['Vulnerable', 'Definetly endangered', 'Critically endangered', 'Severly endangered', 'Extinct']})
df = pd.merge(df, df2, on='day')
df = df.sort_values('num')
dfx = df.groupby(['group'])
dfx.plot(kind='bar', x='day')
# Out:
#   File "<ipython-input-39-c1eb0444a39a>", line 4
#     Count.plot(kind='barh', a)
#                            ^
# SyntaxError: positional argument follows keyword argument

# %%
df=pd.DataFrame({
    'group':['a','a','a','a','a','a','a','b','b','b','b','b','b','b'],
    'day':['Mon','Tues','Fri','Thurs','Sat','Sun','Weds','Fri','Sun','Thurs','Sat','Weds','Mon','Tues'],
    'amount':[1,2,4,2,1,1,2,4,5,3,4,2,1,3]
})
# Calculate the total amount for each day
df_grouped = df.groupby(['day']).sum().amount.reset_index()
# Use Dan's trick to order days names in the table created by groupby
weekdays = ['Mon', 'Tues', 'Weds', 'Thurs', 'Fri', 'Sat', 'Sun']
mapping = {day: i for i, day in enumerate(weekdays)}
key = df_grouped['day'].map(mapping)    
df_grouped = df_grouped.iloc[key.argsort()]
# Draw the bar chart
df_grouped.plot(kind='bar', x='day')

# %%
File_df.head(25)
# Out:
#       ID              Name in English                    Name in French  \
# 0   1022                South Italian                    italien du sud
# 1   1023                     Sicilian                          sicilien
# 2    383                    Low Saxon                         bas-saxon
# 3    335                   Belarusian                        biélorusse
# 4    382                      Lombard                           lombard
# 5    405                       Romani                            romani
# 6   2211             Yiddish (Israel)                  yiddish (Israël)
# 7   1586                        Gondi                             gondi
# 8   1020         Limburgian-Ripuarian  francique ripuaire -limbourgeois
# 9   1943  Quechua of Southern Bolivia           quechua bolivien du sud
# 10  1565                      Kumaoni                           kumaoni
# 11   755                       Aymara                            aymara
# 12   349             Emilian-Romagnol                  émilien-romagnol
# 13   399                  Piedmontese                        piémontais
# 14  1021                      Venetan                          vénitien
# 15  1985                       Zazaki                            zazaki
# 16  1591                Kurux (India)                      kurux (Inde)
# 17  2065                      Tamajeq                           tamajeq
# 18  1585                         Tulu                              tulu
# 19  1556                       Kangdi                            Kangdi
# 20   410                        Scots                             scots
# 21  1026                       Torlak                            torlak
# 22  1476                 West Flemish                flamand occidental
# 23   334                      Bashkir                           bachkir
# 24  1067                      Chechen                        tchétchène
#
#                  Name in Spanish  \
# 0            napolitano-calabrés
# 1                      siciliano
# 2                     bajo sajón
# 3                     bielorruso
# 4                       lombardo
# 5                         romaní
# 6               yiddish (Israel)
# 7                          gondí
# 8           limburgués-ripuarino
# 9   quechua boliviano meridional
# 10                       cumauní
# 11                        aymara
# 12                      emiliano
# 13                     piamontés
# 14                     veneciano
# 15                          zaza
# 16                 kuruj (India)
# 17               tamacheq tahoua
# 18                          tulú
# 19                        kangdi
# 20                       escocés
# 21                        torlak
# 22           flamenco occidental
# 23                        baskir
# 24                      checheno
#
#                                             Countries  \
# 0                                               Italy
# 1                                               Italy
# 2   Germany, Denmark, Netherlands, Poland, Russian...
# 3   Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                  Italy, Switzerland
# 5   Albania, Germany, Austria, Belarus, Bosnia and...
# 6                                              Israel
# 7                                               India
# 8                       Germany, Belgium, Netherlands
# 9                    Bolivia (Plurinational State of)
# 10                                       India, Nepal
# 11      Bolivia (Plurinational State of), Chile, Peru
# 12                                  Italy, San Marino
# 13                                              Italy
# 14                           Croatia, Italy, Slovenia
# 15                                             Turkey
# 16                                              India
# 17                                              Niger
# 18                                              India
# 19                                              India
# 20  United Kingdom of Great Britain and Northern I...
# 21  Albania, Bulgaria, The former Yugoslav Republi...
# 22                       Belgium, France, Netherlands
# 23                                 Russian Federation
# 24                                 Russian Federation
#
#                                 Country codes alpha 3  \
# 0                                                 ITA
# 1                                                 ITA
# 2                             DEU, DNK, NLD, POL, RUS
# 3                        BRB, LVA, LTU, POL, RUS, UKR
# 4                                            ITA, CHE
# 5   ALB, DEU, AUT, BRB, BIH, BGR, HRV, EST, FIN, F...
# 6                                                 ISR
# 7                                                 IND
# 8                                       DEU, BEL, NLD
# 9                                                 BOL
# 10                                           IND, NPL
# 11                                      BOL, CHL, PER
# 12                                           ITA, SMR
# 13                                                ITA
# 14                                      HRV, ITA, SVN
# 15                                                TUR
# 16                                                IND
# 17                                                NER
# 18                                                IND
# 19                                                IND
# 20                                                GBR
# 21                            ALB, BGR, MKD, ROU, SRB
# 22                                      BEL, FRA, NLD
# 23                                                RUS
# 24                                                RUS
#
#                                       ISO639-3 codes Degree of endangerment  \
# 0                                                nap             Vulnerable
# 1                                                scn             Vulnerable
# 2   act, drt, frs, gos, nds, sdz, stl, twd, vel, wep             Vulnerable
# 3                                                bel             Vulnerable
# 4                                                lmo  Definitely endangered
# 5                  rmc, rmf, rml, rmn, rmo, rmw, rmy  Definitely endangered
# 6                                                ydd  Definitely endangered
# 7                                                gon             Vulnerable
# 8                                           ksh, lim             Vulnerable
# 9                                                quh             Vulnerable
# 10                                               kfy             Vulnerable
# 11                                          ayc, ayr             Vulnerable
# 12                                               eml  Definitely endangered
# 13                                               pms  Definitely endangered
# 14                                               vec             Vulnerable
# 15                                               zza             Vulnerable
# 16                                               kru             Vulnerable
# 17                                               thz             Vulnerable
# 18                                               tcy             Vulnerable
# 19                                               xnr  Definitely endangered
# 20                                               sco             Vulnerable
# 21                                     bos, hrv, srp             Vulnerable
# 22                                          vls, zea             Vulnerable
# 23                                               bak             Vulnerable
# 24                                               che             Vulnerable
#
#                                       Alternate names Name in the language  \
# 0   Neapolitan; Neapolitan-Calabrese; неаполитанск...                  NaN
# 1                                                 NaN                  NaN
# 2   Low German, Niedersächsisch, Nedersaksisch, Ni...       Neddersassisch
# 3                                                 NaN                  NaN
# 4                                                 NaN                  NaN
# 5                                  sinti, vlax,  calò                  NaN
# 6                                        Judeo-German                  NaN
# 7   Gondi; Gaudi; Gondiva; Gondwadi; Goondile; Gou...                  NaN
# 8              Colognian (dialect; in German: Kölsch)                  NaN
# 9                                                 NaN                  NaN
# 10         Kumauni; Kamaoni; Kumau; Kumawani; Kumgoni                  NaN
# 11                 Aimara, Jaqi Aru, Southern Aymara.                  NaN
# 12                                                NaN                  NaN
# 13                                                NaN                  NaN
# 14                                                NaN                  NaN
# 15                             Zaza; Dimli; Kirmanjki                  NaN
# 16                                      Kurukh; Oraon                  NaN
# 17                                                NaN                  NaN
# 18     Tuluva Bhasa; Tullu; Thulu; Tal; Tilu; Thalu\n                  NaN
# 19  Dogaryali; Dogri Pahari;  Tokkaru; Dogri-Kangr...                  NaN
# 20      Lallans; Northumbrian (local name in England)                  NaN
# 21           Shop; dialects: Goran, Janjev, Krashovan                  NaN
# 22                Western Flemish; Zeelandic (Zeêuws)                  NaN
# 23                                           Bashkort                  NaN
# 24                                                NaN                  NaN
#
#     Number of speakers                                            Sources  \
# 0            7500000.0                                                NaN
# 1            5000000.0                                                NaN
# 2            4800000.0                                                NaN
# 3            4000000.0  Hienadź Cychun: Weißrussisch. — Lexikon der Sp...
# 4            3500000.0                                                NaN
# 5            3500000.0  Yaron Matras: Romani: a linguistic introductio...
# 6            3000000.0  Neil G. Jacobs: Yiddish: a linguistic introduc...
# 7            2713790.0                                                NaN
# 8            2600000.0                                                NaN
# 9            2300000.0                                                NaN
# 10           2003783.0                                                NaN
# 11           2000000.0  www.inei.gob.pe para  aymara en el Perú (Censo...
# 12           2000000.0                                                NaN
# 13           2000000.0                                                NaN
# 14           2000000.0                          http://www.elgalepin.com/
# 15           2000000.0  Ludwig Paul: Zazaki: Grammatik und Versuch ein...
# 16           1751489.0                                                NaN
# 17           1750000.0  Tuareg organisations (eg Temoust, Lyon see web...
# 18           1722768.0                                                NaN
# 19           1700000.0                                                NaN
# 20           1500000.0                                                NaN
# 21           1500000.0                                                NaN
# 22           1500000.0  Devos, M.& Vandekerckhove, R. (2006). Taal in ...
# 23           1379727.0  А. А. Юлдашев: Башкирский язык. — Языки мира: ...
# 24           1331844.0                                                NaN
#
#     Latitude  Longitude                        Description of the location
# 0    40.9798    15.2490  Campania, Lucania (Basilicata), Abruzzi (Abruz...
# 1    37.4399    14.5019  Sicily (Sicilia), southern and central Calabri...
# 2    53.4029    10.3601  northern Germany, the north-eastern part of th...
# 3    53.9560    27.5756  Belarus except the Polesian-speaking south-wes...
# 4    45.7215     9.3273  the region of Lombardy (except the southernmos...
# 5    46.3165    22.3681  many European countries, most densely in East-...
# 6    32.0833    34.8333  most speakers now live outside Europe, mainly ...
# 7    19.5804    80.4418  Madhya Pradesh (Betul, Chhindwara, Seoni, Mand...
# 8    50.7781     6.0864  Limburg provinces in Belgium and the Netherlan...
# 9   -18.0675   -65.7641  Departments of Cochabamba, Chuquisaca, Potosí ...
# 10   29.4778    79.8486  Uttarakhand, also in Uttar Pradesh, Madhya Pra...
# 11  -16.5835   -68.3020  Departamentos  de Puno,  Moquegua y Tacna, en ...
# 12   44.1270    12.0739  the region of Emilia-Romagna, parts of the pro...
# 13   45.2013     7.8662  Piedmont Region except the Novara Province, th...
# 14   45.4601    12.1948  Veneto region, parts of Friuli-Venezia Giulia,...
# 15   38.8824    40.4846  Tunceli, Erzincan, Elazığ and Bingöl provinces...
# 16   22.1467    85.2758                                Jharkhand and Bihar
# 17   17.2352     8.0859                                                NaN
# 18   12.0178    75.7067                  Karnataka, Andhra Pradesh, Kerala
# 19   32.4356    76.1242                                   Himachal Pradesh
# 20   56.2189    -3.7683  Lowland Scotland and adjacent parts of England...
# 21   42.9644    22.1374  the core area: south-eastern Serbia, the weste...
# 22   51.0275     3.0541  the province of Zealand, the Netherlands; West...
# 23   54.7309    55.9863  the Republic of Bashkortostan and adjacent reg...
# 24   43.1971    45.7031     the Republic of Chechenia and adjacent regions
